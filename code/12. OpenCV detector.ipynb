# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('datasets/images/metro.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap="gray")
plt.show()

# https://docs.opencv.org/3.1.0/d7/d8b/tutorial_py_face_detection.html
models = "C:/opencv/build/etc/haarcascades/"
face_cascade = cv2.CascadeClassifier(models + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(models + 'haarcascade_eye.xml')

# scaleFactor – Parameter specifying how much the image size is reduced at each image scale.
# minNeighbors – Parameter specifying how many neighbors each candidate rectangle should have to retain it.

# TODO: try different scaleFactor, e.g. {1.01, 1.05, 1.1, 1.5, 2, 3, ... }. How these values influence output quality?
faces = face_cascade.detectMultiScale(img, scaleFactor=1.05, minNeighbors=1)
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (255, 255, 255), 2)
plt.imshow(img, cmap="gray")
plt.show()
