# %%
import cv2
import requests
import numpy as np
import matplotlib.pyplot as plt

# %%
url_response = requests.get("https://moblivious.com/wp-content/uploads/2014/05/photo-1.jpg")
img_array = np.array(bytearray(url_response.content), dtype=np.uint8)
print(img_array.shape)
img = cv2.imdecode(img_array, cv2.IMREAD_GRAYSCALE)
print(img.shape)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# (610069,)
# (1224, 1632)

# %% [markdown]
# $r_u = r_d (1 + k*r_d^2)$

# %%
def fix(img, k):
    f = np.zeros(img.shape)

    return f

for k in [0.0000001, 0.000001, 0.00001]:
    print("k =", k)
    fixed = fix(img, k)
    plt.imshow(fixed, cmap='gray')
    plt.show()
# Out:
# k = 1e-07
# k = 1e-06
# k = 1e-05
