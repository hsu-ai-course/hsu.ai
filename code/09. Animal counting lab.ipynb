# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("datasets/images/caribou-2.jpg")

# ... some samples

# %%
# some filtering and morphology done

# %%
n, components = cv2.connectedComponents(closing, connectivity=8)
print("CC =", n)
areas = []
for c in range(1, n):
    area = (components == c).sum()
    areas.append(area)
    
plt.hist(areas, bins=30)
plt.show()
# Out:
# CC = 222
