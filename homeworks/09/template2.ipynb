# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

cap = cv2.VideoCapture('http://50.246.145.122/cgi-bin/faststream.jpg')

for i in range(3):
    ret, frame = cap.read()
    plt.imshow(frame)
    plt.show()
