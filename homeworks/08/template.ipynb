# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('../../code/datasets/images/fish.jpg', cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()
