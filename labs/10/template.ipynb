# %%
# 1
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('../../code/datasets/images/curling.jpg', cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,15))
plt.imshow(img_rgb)
plt.show()

# todo - find and count red and yellow stones
# hints - color clustering, circle detection, filtering :)

# %%
# 2. embed and measure cosine similarity
from gensim.models.doc2vec import Doc2Vec

# unpack a model into 3 files and target the main one
# doc2vec.bin  <---------- this
# doc2vec.bin.syn0.npy
# doc2vec.bin.sin1neg.npy
model = Doc2Vec.load('doc2vec.bin', mmap=None)
print(type(model))
print(type(model.infer_vector(["to", "be", "or", "not"])))

sentences = [
    "This sentence is about fish and sea",
    "How much should I pay for this fish? Sounds like it just was caught in the sea!",
    "Integration is opposite to derivation.",
    "Sine function derivative is cosine function.",
]

# TODO embed sentences using this model https://github.com/jhlau/doc2vec (Associated Press News DBOW (0.6GB))
# estimate pairwise similarity.
# Out:
# <class 'gensim.models.doc2vec.Doc2Vec'>
# <class 'numpy.ndarray'>
