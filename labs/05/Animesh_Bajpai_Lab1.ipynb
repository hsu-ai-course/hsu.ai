# %%
# if not downloaded yet
# nltk.download('punkt')
from collections import defaultdict
import nltk
from nltk import tokenize
from nltk.stem.snowball import SnowballStemmer

# try simple engish
textfile = "datasets/nlp/the old man and the sea.txt"
# or more complex
# textfile = "datasets/nlp/MenOfGoodWill.txt"

stemmer = SnowballStemmer("english")

sentences = []
words = []
lexemes = []
with open(textfile) as f:
    text = f.read().lower()
    
    # lets split text for sentences first
    
    # these 2 parts are the same. Either complex one:
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    sentences = tokenizer.tokenize(text)
    print("Sentences with English punkt:", len(sentences))
    # or "from the box"
    sentences = tokenize.sent_tokenize(text)
    print("Sentences with default method:", len(sentences))

    
    # let's explode sentences to lexemes
    for sentence in sentences:
        if not sentence:
            continue
        s_words = [word for word
                    in tokenize.word_tokenize(sentence)
                    if word not in (',', '.', ':', '-', ';', '?', '!', '"', "``", "`", "''")
                ]
        s_lexemes = [stemmer.stem(word) for word in s_words]
        words.append(s_words)
        lexemes.append(s_lexemes)

# test
print(sentences[400])
print(words[400])
print(lexemes[400])
# Out:
# Sentences with English punkt: 1923
# Sentences with default method: 1923
# he rowed slowly and steadily toward where the bird was circling.
# ['he', 'rowed', 'slowly', 'and', 'steadily', 'toward', 'where', 'the', 'bird', 'was', 'circling']
# ['he', 'row', 'slowli', 'and', 'steadili', 'toward', 'where', 'the', 'bird', 'was', 'circl']

# %%
import itertools

lexicon1 = set(itertools.chain(*words))
print("Words lexicon:", len(lexicon1))

lexicon2 = set(itertools.chain(*lexemes))
print("Words lexicon:", len(lexicon2))

# will the numbers change if you change text file?

# %%
clusters = defaultdict(set)
for i in range(len(lexemes)):
    for j in range(len(lexemes[i])):
        clusters[lexemes[i][j]].add(words[i][j])
        
for key, value in clusters.items():
    if len(value) > 2:
        print(key, value)
# Out:
# fish {'fish', 'fished', 'fishes', 'fishing'}
# form {'formed', 'forms', 'form'}
# see {'see', 'sees', 'seeing'}
# come {'coming', 'comes', 'come'}
# carri {'carrying', 'carried', 'carry'}
# coil {'coiled', 'coil', 'coils'}
# sail {'sails', 'sailing', 'sailed', 'sail'}
# patch {'patch', 'patched', 'patches'}
# look {'looking', 'looks', 'look', 'looked'}
# back {'backing', 'back', 'backed', 'backs'}
# skin {'skinned', 'skinning', 'skin'}
# bring {'bring', 'bringing', 'brings'}
# love {'lovely', 'loved', 'love', 'loving'}
# stay {'stays', 'stay', 'stayed'}
# rememb {'remember', 'remembers', 'remembered'}
# know {'knows', 'know', 'knowing'}
# leav {'leaves', 'leaving', 'leave'}
# show {'showing', 'showed', 'shows', 'show'}
# drift {'drift', 'drifted', 'drifting'}
# plank {'plank', 'planks', 'planking'}
# end {'end', 'ended', 'ends'}
# wait {'waiting', 'waited', 'wait'}
# cut {'cuts', 'cut', 'cutting'}
# salt {'salting', 'salted', 'salt'}
# smell {'smell', 'smelled', 'smelling'}
# drop {'drop', 'drops', 'dropped', 'dropping'}
# think {'thinking', 'thinks', 'think'}
# get {'get', 'gets', 'getting'}
# play {'playing', 'played', 'play'}
# row {'row', 'rows', 'rowing', 'rowed'}
# kill {'kill', 'kills', 'killing', 'killed'}
# club {'club', 'clubbed', 'clubbing'}
# feel {'feeling', 'feel', 'feelings'}
# shiver {'shivered', 'shiver', 'shivering'}
# chop {'chopping', 'chop', 'chopped'}
# confid {'confident', 'confidence', 'confided'}
# bait {'baits', 'bait', 'baited'}
# rise {'rise', 'rises', 'rising'}
# thank {'thank', 'thanked', 'thanks'}
# ask {'asking', 'ask', 'asked'}
# shift {'shifting', 'shifts', 'shift', 'shifted'}
# want {'wants', 'wanted', 'want'}
# light {'lights', 'lighted', 'light', 'lightly', 'lightness'}
# tri {'tried', 'try', 'trying'}
# work {'worked', 'working', 'work'}
# hook {'hooked', 'hooks', 'hook'}
# strang {'strangeness', 'strangely', 'strange'}
# shoulder {'shouldered', 'shoulder', 'shoulders'}
# use {'using', 'used', 'use'}
# thought {'thoughtful', 'thoughts', 'thought'}
# open {'opened', 'opening', 'open'}
# place {'placed', 'place', 'places'}
# clean {'cleanly', 'clean', 'cleaned'}
# make {'making', 'make', 'makes'}
# pound {'pounded', 'pounds', 'pound'}
# keep {'keeping', 'keep', 'keeps'}
# lose {'losing', 'lose', 'loses'}
# care {'carefully', 'care', 'careful'}
# head {'heads', 'head', 'headed'}
# close {'closed', 'closing', 'close'}
# arm {'arms', 'armed', 'arm'}
# start {'starting', 'start', 'started'}
# live {'live', 'lives', 'lived'}
# set {'set', 'setting', 'sets'}
# need {'need', 'needed', 'needs'}
# mean {'mean', 'meaning', 'means'}
# drive {'drives', 'driving', 'drive'}
# hit {'hit', 'hitting', 'hits'}
# talk {'talked', 'talking', 'talk'}
# drink {'drinking', 'drink', 'drinks'}
# prove {'prove', 'proving', 'proved'}
# sleep {'sleeps', 'sleeping', 'sleep'}
# hard {'hardness', 'hard', 'hardly'}
# roll {'rolled', 'rolls', 'rolling'}
# dream {'dream', 'dreaming', 'dreams', 'dreamed'}
# fight {'fights', 'fight', 'fighting'}
# clear {'cleared', 'clearing', 'clearly', 'clear'}
# die {'dies', 'dying', 'died', 'die'}
# turn {'turns', 'turn', 'turned'}
# pull {'pulls', 'pulling', 'pulled', 'pull'}
# move {'move', 'moved', 'moving'}
# lash {'lash', 'lashed', 'lashing', 'lashings'}
# dip {'dipping', 'dip', 'dipped'}
# friend {'friendly', 'friend', 'friends'}
# swallow {'swallowing', 'swallow', 'swallows'}
# beauti {'beautiful', 'beauty', 'beautifully'}
# float {'floated', 'floats', 'floating'}
# solid {'solid', 'solidly', 'solidity'}
# tast {'tasted', 'tasting', 'taste'}
# loop {'looped', 'loops', 'loop'}
# watch {'watch', 'watching', 'watched'}
# circl {'circled', 'circles', 'circle', 'circling'}
# slant {'slant', 'slanting', 'slanted'}
# desper {'desperation', 'desperate', 'desperately'}
# rais {'raised', 'raising', 'raise'}
# cloud {'clouds', 'clouding', 'cloud'}
# poison {'poisonings', 'poisoning', 'poison'}
# rest {'resting', 'rested', 'rest'}
# step {'stepped', 'stepping', 'step'}
# hate {'hated', 'hateful', 'hate'}
# jump {'jumping', 'jumps', 'jumped', 'jump'}
# leap {'leaping', 'leaped', 'leap'}
# travel {'travelled', 'travel', 'travelling', 'travels'}
# increas {'increasing', 'increased', 'increase'}
# steer {'steered', 'steer', 'steering'}
# consid {'consider', 'considering', 'considered'}
# bump {'bumping', 'bumps', 'bumped'}
# pleas {'pleased', 'pleases', 'please'}
# slip {'slipped', 'slip', 'slipping'}
# gain {'gain', 'gaining', 'gained'}
# slow {'slow', 'slowing', 'slowed'}
# jerk {'jerk', 'jerked', 'jerking'}
# cramp {'cramps', 'cramping', 'cramp', 'cramped'}
# chang {'changed', 'change', 'changes'}
# dri {'dried', 'drying', 'dry'}
# comfort {'comfort', 'comfortable', 'comfortably'}
# prepar {'prepare', 'prepared', 'preparation', 'preparing'}
# sever {'severed', 'sever', 'several'}
# bleed {'bleeds', 'bleeding', 'bleed'}
# burn {'burn', 'burned', 'burning'}
# chew {'chewed', 'chewing', 'chew'}
# intellig {'intelligence', 'intelligently', 'intelligent'}
# pass {'pass', 'passed', 'passes'}
# gut {'guts', 'gut', 'gutted'}

# %%
clusters
# Out:
# defaultdict(set,
#             {'the': {'the'},
#              'old': {'old'},
#              'man': {'man'},
#              'and': {'and'},
#              'sea': {'sea', 'seas'},
#              'he': {'he'},
#              'was': {'was'},
#              'an': {'an'},
#              'who': {'who'},
#              'fish': {'fish', 'fished', 'fishes', 'fishing'},
#              'alon': {'alone'},
#              'in': {'in'},
#              'a': {'a'},
#              'skiff': {'skiff'},
#              'gulf': {'gulf'},
#              'stream': {'stream'},
#              'had': {'had'},
#              'gone': {'gone'},
#              'eighty-four': {'eighty-four'},
#              'day': {'day', 'days'},
#              'now': {'now'},
#              'without': {'without'},
#              'take': {'take', 'taking'},
#              'first': {'first'},
#              'forti': {'forty'},
#              'boy': {'boy', 'boys'},
#              'been': {'been'},
#              'with': {'with'},
#              'him': {'him'},
#              'but': {'but'},
#              'after': {'after'},
#              "'s": {"'s"},
#              'parent': {'parents'},
#              'told': {'told'},
#              'that': {'that'},
#              'definit': {'definitely'},
#              'final': {'finally'},
#              '_salao_': {'_salao_'},
#              'which': {'which'},
#              'is': {'is'},
#              'worst': {'worst'},
#              'form': {'form', 'formed', 'forms'},
#              'of': {'of'},
#              'unlucki': {'unlucky'},
#              'at': {'at'},
#              'their': {'their', 'theirs'},
#              'order': {'order', 'orders'},
#              'anoth': {'another'},
#              'boat': {'boat', 'boats'},
#              'caught': {'caught'},
#              'three': {'three'},
#              'good': {'good'},
#              'week': {'week', 'weeks'},
#              'it': {'it', 'its'},
#              'made': {'made'},
#              'sad': {'sad'},
#              'to': {'to'},
#              'see': {'see', 'seeing', 'sees'},
#              'come': {'come', 'comes', 'coming'},
#              'each': {'each'},
#              'his': {'his'},
#              'empti': {'empty'},
#              'alway': {'always'},
#              'went': {'went'},
#              'down': {'down'},
#              'help': {'help'},
#              'carri': {'carried', 'carry', 'carrying'},
#              'either': {'either'},
#              'coil': {'coil', 'coiled', 'coils'},
#              'line': {'line', 'lines'},
#              'or': {'or'},
#              'gaff': {'gaff'},
#              'harpoon': {'harpoon'},
#              'sail': {'sail', 'sailed', 'sailing', 'sails'},
#              'furl': {'furled'},
#              'around': {'around'},
#              'mast': {'mast', 'masts'},
#              'patch': {'patch', 'patched', 'patches'},
#              'flour': {'flour'},
#              'sack': {'sack', 'sacks'},
#              'look': {'look', 'looked', 'looking', 'looks'},
#              'like': {'like', 'liked'},
#              'flag': {'flag'},
#              'perman': {'permanent'},
#              'defeat': {'defeat', 'defeated'},
#              'thin': {'thin', 'thinly'},
#              'gaunt': {'gaunt'},
#              'deep': {'deep'},
#              'wrinkl': {'wrinkles'},
#              'back': {'back', 'backed', 'backing', 'backs'},
#              'neck': {'neck'},
#              'brown': {'brown'},
#              'blotch': {'blotches'},
#              'benevol': {'benevolent'},
#              'skin': {'skin', 'skinned', 'skinning'},
#              'cancer': {'cancer'},
#              'sun': {'sun'},
#              'bring': {'bring', 'bringing', 'brings'},
#              'from': {'from'},
#              'reflect': {'reflected', 'reflection'},
#              'on': {'on'},
#              'tropic': {'tropic'},
#              'were': {'were'},
#              'cheek': {'cheek', 'cheeks'},
#              'ran': {'ran'},
#              'well': {'well', 'wells'},
#              'side': {'side', 'sides'},
#              'face': {'face'},
#              'hand': {'hand', 'hands'},
#              'deep-creas': {'deep-creased'},
#              'scar': {'scars'},
#              'handl': {'handle', 'handling'},
#              'heavi': {'heaviness', 'heavy'},
#              'cord': {'cord', 'cords'},
#              'none': {'none'},
#              'these': {'these'},
#              'fresh': {'fresh'},
#              'they': {'they'},
#              'as': {'as'},
#              'eros': {'erosions'},
#              'fishless': {'fishless'},
#              'desert': {'desert'},
#              'everyth': {'everything'},
#              'about': {'about'},
#              'except': {'except'},
#              'eye': {'eye', 'eyes'},
#              'same': {'same'},
#              'color': {'color'},
#              'cheer': {'cheerful', 'cheerfully'},
#              'undef': {'undefeated'},
#              'santiago': {'santiago'},
#              'said': {'said'},
#              'climb': {'climb', 'climbed'},
#              'bank': {'bank'},
#              'where': {'where'},
#              'haul': {'haul', 'hauled'},
#              'up': {'up'},
#              'i': {'i'},
#              'could': {'could'},
#              'go': {'go', 'going'},
#              'you': {'you'},
#              'again': {'again'},
#              'we': {'we'},
#              've': {"'ve"},
#              'some': {'some'},
#              'money': {'money'},
#              'taught': {'taught'},
#              'love': {'love', 'loved', 'lovely', 'loving'},
#              'no': {'no'},
#              're': {"'re"},
#              'lucki': {'lucky'},
#              'stay': {'stay', 'stayed', 'stays'},
#              'them': {'them'},
#              'rememb': {'remember', 'remembered', 'remembers'},
#              'how': {'how'},
#              'eighty-seven': {'eighty-seven'},
#              'then': {'then'},
#              'big': {'big'},
#              'one': {'one', 'ones'},
#              'everi': {'every'},
#              'for': {'for'},
#              'know': {'know', 'knowing', 'knows'},
#              'did': {'did'},
#              'not': {'not'},
#              'leav': {'leave', 'leaves', 'leaving'},
#              'me': {'me'},
#              'becaus': {'because'},
#              'doubt': {'doubted'},
#              'papa': {'papa'},
#              'am': {'am'},
#              'must': {'must'},
#              'obey': {'obey'},
#              'quit': {'quite'},
#              'normal': {'normal'},
#              'has': {'has'},
#              "n't": {"n't"},
#              'much': {'much'},
#              'faith': {'faith'},
#              'have': {'have'},
#              'yes': {'yes'},
#              'can': {'can', 'cans'},
#              'offer': {'offer'},
#              'beer': {'beer', 'beers'},
#              'terrac': {'terrace'},
#              'll': {"'ll"},
#              'stuff': {'stuff'},
#              'home': {'home'},
#              'whi': {'why'},
#              'between': {'between'},
#              'fishermen': {'fishermen'},
#              'sat': {'sat'},
#              'mani': {'many'},
#              'fun': {'fun'},
#              'angri': {'angry'},
#              'other': {'other', 'others'},
#              'older': {'older'},
#              'show': {'show', 'showed', 'showing', 'shows'},
#              'spoke': {'spoke'},
#              'polit': {'politely'},
#              'current': {'current'},
#              'depth': {'depth', 'depths'},
#              'drift': {'drift', 'drifted', 'drifting'},
#              'steadi': {'steady'},
#              'weather': {'weather'},
#              'what': {'what'},
#              'seen': {'seen'},
#              'success': {'successful'},
#              'alreadi': {'already'},
#              'butcher': {'butchered'},
#              'marlin': {'marlin'},
#              'out': {'out'},
#              'laid': {'laid'},
#              'full': {'full'},
#              'length': {'length'},
#              'across': {'across'},
#              'two': {'two'},
#              'plank': {'plank', 'planking', 'planks'},
#              'men': {'men'},
#              'stagger': {'staggering'},
#              'end': {'end', 'ended', 'ends'},
#              'hous': {'house'},
#              'wait': {'wait', 'waited', 'waiting'},
#              'ice': {'ice'},
#              'truck': {'truck'},
#              'market': {'market'},
#              'havana': {'havana'},
#              'those': {'those'},
#              'shark': {'shark', 'sharks'},
#              'taken': {'taken'},
#              'factori': {'factory'},
#              'cove': {'cove'},
#              'hoist': {'hoist', 'hoisted'},
#              'block': {'block'},
#              'tackl': {'tackle'},
#              'liver': {'liver', 'livers'},
#              'remov': {'removed'},
#              'fin': {'fin', 'fins'},
#              'cut': {'cut', 'cuts', 'cutting'},
#              'off': {'off'},
#              'hide': {'hide', 'hides'},
#              'flesh': {'flesh'},
#              'into': {'into'},
#              'strip': {'strips'},
#              'salt': {'salt', 'salted', 'salting'},
#              'when': {'when'},
#              'wind': {'wind'},
#              'east': {'east'},
#              'smell': {'smell', 'smelled', 'smelling'},
#              'came': {'came'},
#              'harbour': {'harbour', 'harbours'},
#              'today': {'today'},
#              'there': {'there'},
#              'onli': {'only'},
#              'faint': {'faint'},
#              'edg': {'edge', 'edges'},
#              'odour': {'odour'},
#              'north': {'north'},
#              'drop': {'drop', 'dropped', 'dropping', 'drops'},
#              'pleasant': {'pleasant'},
#              'sunni': {'sunny'},
#              'hold': {'hold', 'holding'},
#              'glass': {'glass'},
#              'think': {'think', 'thinking', 'thinks'},
#              'year': {'year', 'years'},
#              'ago': {'ago'},
#              'get': {'get', 'gets', 'getting'},
#              'sardin': {'sardine', 'sardines'},
#              'tomorrow': {'tomorrow'},
#              'play': {'play', 'played', 'playing'},
#              'basebal': {'baseball'},
#              'still': {'still'},
#              'row': {'row', 'rowed', 'rowing', 'rows'},
#              'rogelio': {'rogelio'},
#              'will': {'will'},
#              'throw': {'throw', 'throwing'},
#              'net': {'net'},
#              'would': {'would'},
#              'if': {'if'},
#              'serv': {'serve', 'served'},
#              'way': {'way'},
#              'bought': {'bought'},
#              'are': {'are'},
#              'took': {'took'},
#              'five': {'five'},
#              'near': {'nearly'},
#              'kill': {'kill', 'killed', 'killing', 'kills'},
#              'brought': {'brought'},
#              'too': {'too'},
#              'green': {'green'},
#              'tore': {'tore'},
#              'piec': {'piece', 'pieces'},
#              'tail': {'tail', 'tails'},
#              'slap': {'slapped', 'slapping'},
#              'bang': {'banging'},
#              'thwart': {'thwart'},
#              'break': {'break', 'breaking'},
#              'nois': {'noise'},
#              'club': {'club', 'clubbed', 'clubbing'},
#              'bow': {'bow', 'bows'},
#              'wet': {'wet'},
#              'feel': {'feel', 'feeling', 'feelings'},
#              'whole': {'whole'},
#              'shiver': {'shiver', 'shivered', 'shivering'},
#              'chop': {'chop', 'chopped', 'chopping'},
#              'tree': {'tree'},
#              'sweet': {'sweet'},
#              'blood': {'blood'},
#              'all': {'all'},
#              'over': {'over'},
#              'realli': {'really'},
#              'just': {'just'},
#              'tell': {'tell'},
#              'togeth': {'together'},
#              'sun-burn': {'sun-burned'},
#              'confid': {'confided', 'confidence', 'confident'},
#              'my': {'my'},
#              "'d": {"'d"},
#              'gambl': {'gamble'},
#              'your': {'your', 'yours'},
#              'father': {'father', 'fathers'},
#              'mother': {'mother'},
#              'may': {'may'},
#              'four': {'four'},
#              'bait': {'bait', 'baited', 'baits'},
#              'mine': {'mine'},
#              'left': {'left'},
#              'put': {'put', 'putting'},
#              'box': {'box'},
#              'let': {'let', 'letting'},
#              'hope': {'hope', 'hoped'},
#              'never': {'never'},
#              'freshen': {'freshening'},
#              'breez': {'breeze'},
#              'rise': {'rise', 'rises', 'rising'},
#              'agre': {'agreed'},
#              'steal': {'steal'},
#              'thank': {'thank', 'thanked', 'thanks'},
#              'simpl': {'simple'},
#              'wonder': {'wonder', 'wonderful'},
#              'attain': {'attained'},
#              'humil': {'humility'},
#              'knew': {'knew'},
#              'disgrac': {'disgraceful'},
#              'loss': {'loss'},
#              'true': {'true'},
#              'pride': {'pride'},
#              'be': {'be', 'being'},
#              'this': {'this'},
#              'ask': {'ask', 'asked', 'asking'},
#              'far': {'far'},
#              'shift': {'shift', 'shifted', 'shifting', 'shifts'},
#              'want': {'want', 'wanted', 'wants'},
#              'befor': {'before'},
#              'light': {'light', 'lighted', 'lightly', 'lightness', 'lights'},
#              'tri': {'tried', 'try', 'trying'},
#              'work': {'work', 'worked', 'working'},
#              'hook': {'hook', 'hooked', 'hooks'},
#              'someth': {'something'},
#              'truli': {'truly'},
#              'aid': {'aid'},
#              'doe': {'does'},
#              'such': {'such'},
#              'bird': {'bird', 'birds'},
#              'dolphin': {'dolphin'},
#              'bad': {'bad', 'badly'},
#              'almost': {'almost'},
#              'blind': {'blind'},
#              'strang': {'strange', 'strangely', 'strangeness'},
#              'turtle-': {'turtle-ing'},
#              'mosquito': {'mosquito'},
#              'coast': {'coast'},
#              'strong': {'strong', 'strongly'},
#              'enough': {'enough'},
#              'so': {'so'},
#              'trick': {'trick', 'tricks'},
#              'us': {'us'},
#              'cast': {'cast'},
#              'pick': {'pick', 'picked'},
#              'gear': {'gear'},
#              'shoulder': {'shoulder', 'shouldered', 'shoulders'},
#              'wooden': {'wooden'},
#              'hard-braid': {'hard-braided'},
#              'shaft': {'shaft'},
#              'under': {'under'},
#              'stern': {'stern'},
#              'along': {'along'},
#              'use': {'use', 'used', 'using'},
#              'subdu': {'subdue'},
#              'alongsid': {'alongside'},
#              'better': {'better'},
#              'dew': {'dew'},
#              'though': {'though'},
#              'sure': {'sure', 'surely'},
#              'local': {'local'},
#              'peopl': {'people'},
#              'thought': {'thought', 'thoughtful', 'thoughts'},
#              'needless': {'needless'},
#              'temptat': {'temptation', 'temptations'},
#              'walk': {'walk', 'walked'},
#              'road': {'road'},
#              'shack': {'shack'},
#              'through': {'through'},
#              'open': {'open', 'opened', 'opening'},
#              'door': {'door'},
#              'lean': {'leaned', 'leaning'},
#              'wrap': {'wrapped', 'wrapping'},
#              'against': {'against'},
#              'wall': {'wall', 'walls'},
#              'besid': {'beside', 'besides'},
#              'long': {'long'},
#              'room': {'room'},
#              'tough': {'tough'},
#              'bud-shield': {'bud-shields'},
#              'royal': {'royal'},
#              'palm': {'palm', 'palms'},
#              'call': {'call', 'called'},
#              '_guano_': {'_guano_'},
#              'bed': {'bed'},
#              'tabl': {'table'},
#              'chair': {'chair', 'chairs'},
#              'place': {'place', 'placed', 'places'},
#              'dirt': {'dirt'},
#              'floor': {'floor'},
#              'cook': {'cook', 'cooked'},
#              'charcoal': {'charcoal'},
#              'flatten': {'flattened'},
#              'overlap': {'overlapping'},
#              'sturdi': {'sturdy'},
#              'fiber': {'fibered'},
#              'pictur': {'picture'},
#              'sacr': {'sacred'},
#              'heart': {'heart'},
#              'jesus': {'jesus'},
#              'virgin': {'virgin'},
#              'cobr': {'cobre'},
#              'relic': {'relics'},
#              'wife': {'wife'},
#              'onc': {'once'},
#              'tint': {'tinted'},
#              'photograph': {'photograph'},
#              'lone': {'lonely'},
#              'shelf': {'shelf'},
#              'corner': {'corner'},
#              'clean': {'clean', 'cleaned', 'cleanly'},
#              'shirt': {'shirt'},
#              'do': {'do', 'doing'},
#              'eat': {'eat', 'eating'},
#              'pot': {'pot'},
#              'yellow': {'yellow'},
#              'rice': {'rice'},
#              'make': {'make', 'makes', 'making'},
#              'fire': {'fire'},
#              'later': {'later'},
#              'cold': {'cold', 'colds'},
#              'cours': {'course'},
#              'sold': {'sold'},
#              'fiction': {'fiction'},
#              'eighty-f': {'eighty-five'},
#              'number': {'number'},
#              'dress': {'dressed', 'dresses'},
#              'thousand': {'thousand'},
#              'pound': {'pound', 'pounded', 'pounds'},
#              'sit': {'sit', 'sitting'},
#              'doorway': {'doorway'},
#              'yesterday': {'yesterday'},
#              'paper': {'paper', 'papers'},
#              'read': {'read'},
#              'whether': {'whether'},
#              'perico': {'perico'},
#              'gave': {'gave'},
#              '_bodega_': {'_bodega_'},
#              'explain': {'explain', 'explained'},
#              'keep': {'keep', 'keeping', 'keeps'},
#              'share': {'share'},
#              'morn': {'morning'},
#              'yanke': {'yankees'},
#              'lose': {'lose', 'loses', 'losing'},
#              'fear': {'fear', 'feared'},
#              'indian': {'indians'},
#              'cleveland': {'cleveland'},
#              'son': {'son'},
#              'great': {'great', 'greatness'},
#              'dimaggio': {'dimaggio'},
#              'both': {'both'},
#              'tiger': {'tigers'},
#              'detroit': {'detroit'},
#              'care': {'care', 'careful', 'carefully'},
#              'even': {'even', 'evening'},
#              'red': {'red', 'reds'},
#              'cincinnati': {'cincinnati'},
#              'white': {'white'},
#              'sox': {'sox'},
#              'chicago': {'chicago'},
#              'studi': {'study'},
#              'should': {'should'},
#              'buy': {'buy'},
#              'termin': {'terminal'},
#              'lotteri': {'lottery'},
#              'eighty-fifth': {'eighty-fifth'},
#              'record': {'record'},
#              'happen': {'happen', 'happened'},
#              'twice': {'twice'},
#              'find': {'find', 'finding'},
#              'sheet': {'sheet'},
#              'dollar': {'dollars'},
#              'half': {'half'},
#              'borrow': {'borrow'},
#              'easi': {'easy'},
#              'perhap': {'perhaps'},
#              'beg': {'beg', 'begged'},
#              'warm': {'warm'},
#              'septemb': {'september'},
#              'month': {'month', 'months'},
#              'anyon': {'anyone'},
#              'fisherman': {'fisherman'},
#              'asleep': {'asleep'},
#              'armi': {'army'},
#              'blanket': {'blanket'},
#              'spread': {'spread'},
#              'power': {'power', 'powerful'},
#              'although': {'although'},
#              'veri': {'very'},
#              'creas': {'creases'},
#              'head': {'head', 'headed', 'heads'},
#              'fallen': {'fallen'},
#              'forward': {'forward'},
#              'time': {'time', 'times'},
#              'fade': {'faded'},
#              'differ': {'difference', 'different'},
#              'shade': {'shade', 'shades'},
#              'by': {'by'},
#              'close': {'close', 'closed', 'closing'},
#              'life': {'life'},
#              'newspap': {'newspaper', 'newspapers'},
#              'lay': {'lay'},
#              'knee': {'knee', 'knees'},
#              'weight': {'weight'},
#              'arm': {'arm', 'armed', 'arms'},
#              'held': {'held'},
#              'barefoot': {'barefoot', 'barefooted'},
#              'wake': {'wake', 'waking'},
#              'moment': {'moment'},
#              'away': {'away'},
#              'smile': {'smiled'},
#              'got': {'got'},
#              'supper': {'supper'},
#              "'m": {"'m"},
#              'hungri': {'hungry'},
#              'ca': {'ca'},
#              'fold': {'fold', 'folding'},
#              'start': {'start', 'started', 'starting'},
#              'while': {'while'},
#              'aliv': {'alive'},
#              'live': {'live', 'lived', 'lives'},
#              'yourself': {'yourself'},
#              'black': {'black', 'blackness'},
#              'bean': {'beans'},
#              'fri': {'fried'},
#              'banana': {'bananas'},
#              'stew': {'stew'},
#              'two-deck': {'two-decker'},
#              'metal': {'metal'},
#              'contain': {'container'},
#              'set': {'set', 'sets', 'setting'},
#              'knive': {'knives'},
#              'fork': {'forks'},
#              'spoon': {'spoon', 'spoons'},
#              'pocket': {'pocket'},
#              'napkin': {'napkin'},
#              'martin': {'martin'},
#              'owner': {'owner'},
#              'need': {'need', 'needed', 'needs'},
#              'give': {'give'},
#              'belli': {'belly'},
#              'meat': {'meat'},
#              'done': {'done'},
#              'more': {'more'},
#              'than': {'than'},
#              'sent': {'sent'},
#              'best': {'best'},
#              'bottl': {'bottle', 'bottles'},
#              'hatuey': {'hatuey'},
#              'kind': {'kind', 'kindness'},
#              'gentl': {'gentle', 'gently'},
#              'wish': {'wish', 'wished'},
#              'until': {'until'},
#              'readi': {'ready'},
#              'wash.': {'wash.'},
#              'wash': {'wash', 'washed'},
#              'villag': {'village'},
#              'water': {'water'},
#              'suppli': {'supply'},
#              'street': {'street', 'streets'},
#              'here': {'here'},
#              'soap': {'soap'},
#              'towel': {'towel'},
#              'thoughtless': {'thoughtless'},
#              'jacket': {'jacket'},
#              'winter': {'winter'},
#              'sort': {'sort', 'sorts'},
#              'shoe': {'shoes'},
#              'excel': {'excellent'},
#              'american': {'american'},
#              'leagu': {'league', 'leagues'},
#              'happili': {'happily'},
#              'lost': {'lost'},
#              'mean': {'mean', 'meaning', 'means'},
#              'noth': {'nothing'},
#              'himself': {'himself'},
#              'team': {'team'},
#              'natur': {'naturally'},
#              'brooklyn': {'brooklyn'},
#              'philadelphia': {'philadelphia'},
#              'dick': {'dick'},
#              'sisler': {'sisler'},
#              'drive': {'drive', 'drives', 'driving'},
#              'park': {'park'},
#              'ever': {'ever'},
#              'hit': {'hit', 'hits', 'hitting'},
#              'longest': {'longest'},
#              'ball': {'ball'},
#              'timid': {'timid'},
#              'mistak': {'mistake'},
#              'might': {'might'},
#              'our': {'our'},
#              'say': {'say'},
#              'mayb': {'maybe'},
#              'poor': {'poor'},
#              'understand': {'understand', 'understanding'},
#              'age': {'age'},
#              'squar': {'square', 'squarely'},
#              'rig': {'rig', 'rigged'},
#              'ship': {'ship', 'shipped'},
#              'africa': {'africa'},
#              'lion': {'lions'},
#              'beach': {'beach', 'beaches'},
#              'talk': {'talk', 'talked', 'talking'},
#              'john': {'john'},
#              'j': {'j'},
#              'mcgraw': {'mcgraw'},
#              '_jota_': {'_jota_'},
#              'sometim': {'sometimes'},
#              'rough': {'rough'},
#              'harsh-spoken': {'harsh-spoken'},
#              'difficult': {'difficult'},
#              'drink': {'drink', 'drinking', 'drinks'},
#              'mind': {'mind'},
#              'hors': {'horse', 'horses'},
#              'least': {'least'},
#              'list': {'lists'},
#              'frequent': {'frequently'},
#              'name': {'name', 'names'},
#              'telephon': {'telephone'},
#              'manag': {'manager'},
#              'greatest': {'greatest'},
#              'most': {'most'},
#              'duroch': {'durocher'},
#              'continu': {'continue', 'continued'},
#              'luqu': {'luque'},
#              'mike': {'mike'},
#              'gonzalez': {'gonzalez'},
#              'equal': {'equal'},
#              '_qué': {'_qué'},
#              'va_': {'va_'},
#              'happi': {'happy'},
#              'prove': {'prove', 'proved', 'proving'},
#              'wrong': {'wrong'},
#              'resolut': {'resolution'},
#              'ought': {'ought'},
#              'thing': {'thing', 'things'},
#              'night': {'night'},
#              'alarm': {'alarm'},
#              'clock': {'clock'},
#              'earli': {'early'},
#              'longer': {'longer'},
#              'young': {'young'},
#              'sleep': {'sleep', 'sleeping', 'sleeps'},
#              'late': {'late'},
#              'hard': {'hard', 'hardly', 'hardness'},
#              'waken': {'waken'},
#              'inferior': {'inferior'},
#              'eaten': {'eaten'},
#              'trouser': {'trousers'},
#              'dark': {'dark', 'darkness'},
#              'roll': {'rolled', 'rolling', 'rolls'},
#              'pillow': {'pillow'},
#              'insid': {'inside'},
#              'slept': {'slept'},
#              'cover': {'covered'},
#              'spring': {'spring', 'springs'},
#              'short': {'short'},
#              'dream': {'dream', 'dreamed', 'dreaming', 'dreams'},
#              'golden': {'golden'},
#              'hurt': {'hurt'},
#              'high': {'high'},
#              'cape': {'capes'},
#              'mountain': {'mountains'},
#              'heard': {'heard'},
#              'surf': {'surf'},
#              'roar': {'roar'},
#              'saw': {'saw', 'sawed'},
#              'nativ': {'native'},
#              'ride': {'riding'},
#              'tar': {'tar'},
#              'oakum': {'oakum'},
#              'deck': {'deck'},
#              'land': {'land'},
#              'usual': {'usual', 'usually'},
#              'woke': {'woke'},
#              'tonight': {'tonight'},
#              'peak': {'peaks'},
#              'island': {'island', 'islands'},
#              'roadstead': {'roadsteads'},
#              'canari': {'canary'},
#              'storm': {'storm', 'storms'},
#              'nor': {'nor'},
#              'women': {'women'},
#              'occurr': {'occurrences'},
#              'fight': {'fight', 'fighting', 'fights'},
#              'contest': {'contestant', 'contests'},
#              'strength': {'strength'},
#              'cat': {'cat', 'cats'},
#              'dusk': {'dusk'},
#              'simpli': {'simply'},
#              'moon': {'moon'},
#              'unrol': {'unrolled', 'unrolling'},
#              'urin': {'urinated'},
#              'outsid': {'outside'},
#              'soon': {'soon'},
#              'unlock': {'unlocked'},
#              'quiet': {'quiet', 'quietly'},
#              'bare': {'bare', 'barely'},
#              'feet': {'feet'},
#              'cot': {'cot'},
#              'clear': {'clear', 'cleared', 'clearing', 'clearly'},
#              'die': {'die', 'died', 'dies', 'dying'},
#              'foot': {'foot'},
#              'turn': {'turn', 'turned', 'turns'},
#              'nod': {'nodded'},
#              'pull': {'pull', 'pulled', 'pulling', 'pulls'},
#              'sleepi': {'sleepy'},
#              'sorri': {'sorry'},
#              'move': {'move', 'moved', 'moving'},
#              'reach': {'reach', 'reached'},
#              'basket': {'basket'},
#              'coffe': {'coffee'},
#              'condens': {'condensed'},
#              'milk': {'milk'},
#              'manolin': {'manolin'},
#              'anyth': {'anything'},
#              'right': {'right', 'righted'},
#              'credit': {'credit'},
#              'bare-foot': {'bare-footed'},
#              'coral': {'coral'},
#              'rock': {'rock', 'rocks'},
#              'store': {'stored'},
#              'drank': {'drank'},
#              'slowli': {'slowly'},
#              'bore': {'bored'},
#              'lunch': {'lunch'},
#              'trail': {'trail', 'trailing'},
#              'pebbl': {'pebbled'},
#              'sand': {'sand'},
#              'lift': {'lifted'},
#              'slid': {'slid'},
#              'her': {'her'},
#              'luck': {'luck'},
#              'fit': {'fit', 'fitted'},
#              'rope': {'rope'},
#              'lash': {'lash', 'lashed', 'lashing', 'lashings'},
#              'oar': {'oar', 'oars'},
#              'onto': {'onto'},
#              'thole': {'thole'},
#              'pin': {'pins'},
#              'thrust': {'thrust', 'thrusting'},
#              'blade': {'blade', 'blades'},
#              'began': {'began'},
#              'dip': {'dip', 'dipped', 'dipping'},
#              'push': {'push', 'pushed'},
#              'below': {'below'},
#              'hill': {'hill', 'hills'},
#              'someon': {'someone'},
#              'speak': {'speak', 'speaking'},
#              'silent': {'silent'},
#              'apart': {'apart'},
#              'mouth': {'mouth'},
#              'part': {'part', 'parts'},
#              'ocean': {'ocean'},
#              'behind': {'behind'},
#              'phosphoresc': {'phosphorescence', 'phosphorescent'},
#              'weed': {'weed'},
#              'sudden': {'sudden', 'suddenly'},
#              'seven': {'seven'},
#              'hundr': {'hundred'},
#              'fathom': {'fathoms'},
#              'congreg': {'congregated'},
#              'swirl': {'swirl', 'swirls'},
#              'steep': {'steep'},
#              'concentr': {'concentrations'},
#              'shrimp': {'shrimp', 'shrimps'},
#              'school': {'school', 'schools'},
#              'squid': {'squid'},
#              'deepest': {'deepest'},
#              'hole': {'hole', 'holes'},
#              'rose': {'rose'},
#              'surfac': {'surface'},
#              'wander': {'wandering'},
#              'fed': {'fed'},
#              'trembl': {'trembling'},
#              'sound': {'sound', 'sounds'},
#              'fli': {'fly', 'flying'},
#              'hiss': {'hissing'},
#              'stiff': {'stiff'},
#              'wing': {'wings'},
#              'soar': {'soared'},
#              'fond': {'fond'},
#              'princip': {'principal'},
#              'friend': {'friend', 'friendly', 'friends'},
#              'especi': {'especially'},
#              'small': {'small'},
#              'delic': {'delicate', 'delicately'},
#              'tern': {'terns'},
#              'harder': {'harder'},
#              'robber': {'robber'},
#              'fine': {'fine'},
#              'swallow': {'swallow', 'swallowing', 'swallows'},
#              'cruel': {'cruel'},
#              'she': {'she'},
#              'beauti': {'beautiful', 'beautifully', 'beauty'},
#              'hunt': {'hunting'},
#              'voic': {'voice', 'voices'},
#              '_la': {'_la'},
#              'mar_': {'mar_'},
#              'spanish': {'spanish'},
#              'woman': {'woman'},
#              'younger': {'younger'},
#              'buoy': {'buoys'},
#              'float': {'floated', 'floating', 'floats'},
#              'motorboat': {'motorboats'},
#              '_el': {'_el'},
#              'masculin': {'masculine'},
#              'enemi': {'enemies', 'enemy'},
#              'feminin': {'feminine'},
#              'withheld': {'withheld'},
#              'favour': {'favours'},
#              'wild': {'wild', 'wildly'},
#              'wick': {'wicked'},
#              'affect': {'affects'},
#              'steadili': {'steadily'},
#              'effort': {'effort'},
#              'sinc': {'since'},
#              'kept': {'kept'},
#              'within': {'within'},
#              'speed': {'speed', 'speeded'},
#              'flat': {'flat'},
#              'occasion': {'occasional'},
#              'third': {'third'},
#              'further': {'further'},
#              'hour': {'hour', 'hours'},
#              'bonita': {'bonita'},
#              'albacor': {'albacore', 'albacores'},
#              'second': {'second'},
#              'seventy-f': {'seventy-five'},
#              'fourth': {'fourth'},
#              'blue': {'blue'},
#              'twenty-f': {'twenty-five'},
#              'hung': {'hung'},
#              'shank': {'shank'},
#              'tie': {'tied'},
#              'sew': {'sewed'},
#              'solid': {'solid', 'solidity', 'solidly'},
#              'project': {'projected', 'projecting'},
#              'curv': {'curve'},
#              'point': {'point', 'pointed'},
#              'half-garland': {'half-garland'},
#              'steel': {'steel'},
#              'tast': {'taste', 'tasted', 'tasting'},
#              'given': {'given'},
#              'tuna': {'tuna', 'tunas'},
#              'plummet': {'plummets'},
#              'runner': {'runner'},
#              'jack': {'jack'},
#              'condit': {'condition'},
#              'scent': {'scent'},
#              'attract': {'attract', 'attractiveness'},
#              'thick': {'thick'},
#              'pencil': {'pencil'},
#              'loop': {'loop', 'looped', 'loops'},
#              'green-sap': {'green-sapped'},
#              'stick': {'stick', 'sticks'},
#              'ani': {'any'},
#              'touch': {'touch', 'touching'},
#              'forty-fathom': {'forty-fathom'},
#              'fast': {'fast'},
#              'spare': {'spare'},
#              'necessari': {'necessary'},
#              'watch': {'watch', 'watched', 'watching'},
#              'straight': {'straight'},
#              'proper': {'proper', 'properly'},
#              'low': {'low'},
#              'toward': {'toward'},
#              'shore': {'shore'},
#              'brighter': {'brighter'},
#              'glare': {'glare'},
#              'sharpli': {'sharply'},
#              'straighter': {'straighter'},
#              'level': {'level'},
#              'exact': {'exact', 'exactly'},
#              'swam': {'swam'},
#              'sixti': {'sixty'},
#              'precis': {'precision'},
#              'new': {'new'},
#              'rather': {'rather'},
#              'higher': {'higher'},
#              'sight': {'sight'},
#              'inshor': {'inshore'},
#              'yet': {'yet'},
#              'forc': {'force', 'forced'},
#              'pain': {'pain', 'painful'},
#              'man-of-war': {'man-of-war'},
#              'circl': {'circle', 'circled', 'circles', 'circling'},
#              'sky': {'sky'},
#              'ahead': {'ahead'},
#              'quick': {'quick', 'quickly'},
#              'slant': {'slant', 'slanted', 'slanting'},
#              'back-swept': {'back-swept'},
#              'aloud': {'aloud'},
#              'hurri': {'hurry'},
#              'crowd': {'crowded'},
#              'littl': {'little'},
#              'correct': {'correctly'},
#              'faster': {'faster'},
#              'air': {'air'},
#              'motionless': {'motionless'},
#              'dove': {'dove'},
#              'spurt': {'spurt'},
#              'desper': {'desperate', 'desperately', 'desperation'},
#              'wire': {'wire'},
#              'leader': {'leader', 'leaders'},
#              'medium-s': {'medium-sized'},
#              'ring': {'ring'},
#              'bolt': {'bolt'},
#              'long-wing': {'long-winged'},
#              'dive': {'dive'},
#              'swing': {'swing', 'swinging'},
#              'ineffectu': {'ineffectual', 'ineffectually'},
#              'follow': {'followed', 'following'},
#              'slight': {'slight', 'slightly'},
#              'bulg': {'bulge', 'bulged'},
#              'rais': {'raise', 'raised', 'raising'},
#              'escap': {'escaping'},
#              'flight': {'flight'},
#              'wide': {'wide'},
#              'chanc': {'chance', 'chances'},
#              'burst': {'burst', 'bursting'},
#              'movement': {'movement', 'movements'},
#              'gotten': {'gotten'},
#              'stray': {'stray'},
#              'somewher': {'somewhere'},
#              'cloud': {'cloud', 'clouding', 'clouds'},
#              'gray': {'gray'},
#              'purpl': {'purple'},
#              'sift': {'sifting'},
#              'plankton': {'plankton'},
#              'meant': {'meant'},
#              'shape': {'shape', 'shaped'},
#              'sun-bleach': {'sun-bleached'},
#              'sargasso': {'sargasso'},
#              'formal': {'formalized'},
#              'iridesc': {'iridescent'},
#              'gelatin': {'gelatinous'},
#              'bladder': {'bladder'},
#              'portugues': {'portuguese'},
#              'itself': {'itself'},
#              'bubbl': {'bubble', 'bubbles'},
#              'dead': {'dead', 'deadly'},
#              'filament': {'filaments'},
#              'yard': {'yard', 'yards'},
#              '_agua': {'_agua'},
#              'mala_': {'mala_'},
#              'whore': {'whore'},
#              'swung': {'swung'},
#              'tini': {'tiny'},
#              'colour': {'colour', 'coloured'},
#              'immun': {'immune'},
#              'poison': {'poison', 'poisoning', 'poisonings'},
#              'catch': {'catch'},
#              'rest': {'rest', 'rested', 'resting'},
#              'slimi': {'slimy'},
#              'welt': {'welts'},
#              'sore': {'sore', 'sores'},
#              'ivi': {'ivy'},
#              'oak': {'oak'},
#              'struck': {'struck'},
#              'whiplash': {'whiplash'},
#              'falsest': {'falsest'},
#              'turtl': {'turtle', 'turtles'},
#              'approach': {'approached'},
#              'front': {'front'},
#              'shut': {'shut'},
#              ...})
