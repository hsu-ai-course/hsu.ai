# %%
import nltk
from nltk import tokenize
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english")
def load_database(textfile):
    sentences = []
    words = []
    lexemes = []
    with open(textfile) as f:
        text = f.read().lower()
        sentences = tokenize.sent_tokenize(text)
        for sentence in sentences:
            if not sentence:
                continue
            s_words = [word for word
                        in tokenize.word_tokenize(sentence)
                        if word not in (',', '.', ':', '-', ';', '?', '!', '"', "``", "`", "''")
                    ]
            s_lexemes = [stemmer.stem(word) for word in s_words]
            words.append(s_words)
            lexemes.append(s_lexemes)
    return sentences, words, lexemes

# %%
sentences, words, lexemes = load_database("datasets/nlp/the old man and the sea.txt")
print(lexemes)
# Out:
# [['the', 'old', 'man', 'and', 'the', 'sea', 'he', 'was', 'an', 'old', 'man', 'who', 'fish', 'alon', 'in', 'a', 'skiff', 'in', 'the', 'gulf', 'stream', 'and', 'he', 'had', 'gone', 'eighty-four', 'day', 'now', 'without', 'take', 'a', 'fish'], ['in', 'the', 'first', 'forti', 'day', 'a', 'boy', 'had', 'been', 'with', 'him'], ['but', 'after', 'forti', 'day', 'without', 'a', 'fish', 'the', 'boy', "'s", 'parent', 'had', 'told', 'him', 'that', 'the', 'old', 'man', 'was', 'now', 'definit', 'and', 'final', '_salao_', 'which', 'is', 'the', 'worst', 'form', 'of', 'unlucki', 'and', 'the', 'boy', 'had', 'gone', 'at', 'their', 'order', 'in', 'anoth', 'boat', 'which', 'caught', 'three', 'good', 'fish', 'the', 'first', 'week'], ['it', 'made', 'the', 'boy', 'sad', 'to', 'see', 'the', 'old', 'man', 'come', 'in', 'each', 'day', 'with', 'his', 'skiff', 'empti', 'and', 'he', 'alway', 'went', 'down', 'to', 'help', 'him', 'carri', 'either', 'the', 'coil', 'line', 'or', 'the', 'gaff', 'and', 'harpoon', 'and', 'the', 'sail', 'that', 'was', 'furl', 'around', 'the', 'mast'], ['the', 'sail', 'was', 'patch', 'with', 'flour', 'sack', 'and', 'furl', 'it', 'look', 'like', 'the', 'flag', 'of', 'perman', 'defeat'], ['the', 'old', 'man', 'was', 'thin', 'and', 'gaunt', 'with', 'deep', 'wrinkl', 'in', 'the', 'back', 'of', 'his', 'neck'], ['the', 'brown', 'blotch', 'of', 'the', 'benevol', 'skin', 'cancer', 'the', 'sun', 'bring', 'from', 'it', 'reflect', 'on', 'the', 'tropic', 'sea', 'were', 'on', 'his', 'cheek'], ['the', 'blotch', 'ran', 'well', 'down', 'the', 'side', 'of', 'his', 'face', 'and', 'his', 'hand', 'had', 'the', 'deep-creas', 'scar', 'from', 'handl', 'heavi', 'fish', 'on', 'the', 'cord'], ['but', 'none', 'of', 'these', 'scar', 'were', 'fresh'], ['they', 'were', 'as', 'old', 'as', 'eros', 'in', 'a', 'fishless', 'desert'], ['everyth', 'about', 'him', 'was', 'old', 'except', 'his', 'eye', 'and', 'they', 'were', 'the', 'same', 'color', 'as', 'the', 'sea', 'and', 'were', 'cheer', 'and', 'undef'], ['santiago', 'the', 'boy', 'said', 'to', 'him', 'as', 'they', 'climb', 'the', 'bank', 'from', 'where', 'the', 'skiff', 'was', 'haul', 'up'], ['i', 'could', 'go', 'with', 'you', 'again'], ['we', 've', 'made', 'some', 'money'], ['the', 'old', 'man', 'had', 'taught', 'the', 'boy', 'to', 'fish', 'and', 'the', 'boy', 'love', 'him'], ['no', 'the', 'old', 'man', 'said'], ['you', 're', 'with', 'a', 'lucki', 'boat'], ['stay', 'with', 'them'], ['but', 'rememb', 'how', 'you', 'went', 'eighty-seven', 'day', 'without', 'fish', 'and', 'then', 'we', 'caught', 'big', 'one', 'everi', 'day', 'for', 'three', 'week'], ['i', 'rememb', 'the', 'old', 'man', 'said'], ['i', 'know', 'you', 'did', 'not', 'leav', 'me', 'becaus', 'you', 'doubt'], ['it', 'was', 'papa', 'made', 'me', 'leav'], ['i', 'am', 'a', 'boy', 'and', 'i', 'must', 'obey', 'him'], ['i', 'know', 'the', 'old', 'man', 'said'], ['it', 'is', 'quit', 'normal'], ['he', 'has', "n't", 'much', 'faith'], ['no', 'the', 'old', 'man', 'said'], ['but', 'we', 'have'], ['have', "n't", 'we'], ['yes', 'the', 'boy', 'said'], ['can', 'i', 'offer', 'you', 'a', 'beer', 'on', 'the', 'terrac', 'and', 'then', 'we', 'll', 'take', 'the', 'stuff', 'home'], ['whi', 'not'], ['the', 'old', 'man', 'said'], ['between', 'fishermen'], ['they', 'sat', 'on', 'the', 'terrac', 'and', 'mani', 'of', 'the', 'fishermen', 'made', 'fun', 'of', 'the', 'old', 'man', 'and', 'he', 'was', 'not', 'angri'], ['other', 'of', 'the', 'older', 'fishermen', 'look', 'at', 'him', 'and', 'were', 'sad'], ['but', 'they', 'did', 'not', 'show', 'it', 'and', 'they', 'spoke', 'polit', 'about', 'the', 'current', 'and', 'the', 'depth', 'they', 'had', 'drift', 'their', 'line', 'at', 'and', 'the', 'steadi', 'good', 'weather', 'and', 'of', 'what', 'they', 'had', 'seen'], ['the', 'success', 'fishermen', 'of', 'that', 'day', 'were', 'alreadi', 'in', 'and', 'had', 'butcher', 'their', 'marlin', 'out', 'and', 'carri', 'them', 'laid', 'full', 'length', 'across', 'two', 'plank', 'with', 'two', 'men', 'st ...

# %%
# TODO: write the code that will find ALL sentences which contain all words of query
def exact_match(query):
    result = []
    query = query.lower()
    stemmed = [stemmer.stem(word) for word in query.split()]
    for token in lexemes:
        if stemmed[0] in token and stemmed[1] in token and stemmed[2] in token:
            result.append(" ".join(token))
    
    # TODO
    # query -> [lexemes] -> [stems]
    # go through all bags of words
    # if bag contains ALL query stems - append to result
    return result

# TODO: write the code that will find TOP sentences with THE BEST matches with query
def ranked_match(query, top=5):
    ranked_result = []
    query.split()

    # TODO
    # query -> [lexemes] -> [stems]
    # go through all bags of words
    # if bag contains ALL query stems - append len(intersection) to result_result
    
    ranked_result.sort(reverse=True)
    return [item[1] for item in ranked_result[-top:]]

# %%
print(exact_match("yellow Gulf weed"))
print(ranked_match("yellow Gulf weed"))
# Out:
# ['it was the yellow gulf weed that had made so much phosphorescence in the night.', 'so he hooked a patch of yellow gulf weed with the gaff as they passed and shook it so that the small shrimps that were in it fell onto the planking of the skiff.']
# []
